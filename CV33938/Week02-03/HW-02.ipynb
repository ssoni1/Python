# %%
import random
import matplotlib.pyplot as plt
trial_count = 500
R=0
def fair_die_simulation(trials):                                
   
    simulations = []
    options = [1,2,3,4,5,6]
    for i in range(trial_count):                          
       simulations += [random.randint(1,len(options))]
    return simulations
fair_die = fair_die_simulation(trial_count)

plt.hist(fair_die,density=True,bins=20)
plt.title('Simulation of Biased Die')
plt.ylabel('Time')
plt.xlabel('Die Numbers')
# Out:
# Text(0.5, 0, 'Die Numbers')

# %%
def biased_die_simuations(trials, weights=[0.25, 0.15, 0.15, 0.15, 0.15, 0.15]):
    options = [1,2,3,4,5,6]
    simulations = []
   # biasedRoll = 0
    for i in range(trials):
        R=0
        R=random.choices(options,weights)[0]
        simulations.append(R)
    return simulations
biasedRoll = (biased_die_simuations(500))
print(biasedRoll)
print(biasedRoll.count(1))
print(biasedRoll.count(2))
print(biasedRoll.count(3))
print(biasedRoll.count(4))
print(biasedRoll.count(5))
print(biasedRoll.count(6))

plt.hist(randRoll,density=True,bins=20)
plt.title('Simulation of Biased Die')
plt.ylabel('Time')
plt.xlabel('Die Nunbers')
# Out:
# [5, 1, 2, 3, 3, 1, 1, 4, 1, 1, 4, 1, 1, 4, 2, 1, 1, 6, 2, 5, 5, 1, 1, 4, 1, 2, 1, 3, 2, 3, 6, 4, 6, 3, 1, 2, 3, 5, 5, 3, 1, 1, 6, 1, 1, 1, 2, 5, 5, 1, 5, 1, 5, 1, 6, 5, 2, 6, 3, 1, 2, 1, 6, 5, 3, 2, 1, 1, 6, 4, 2, 4, 5, 1, 2, 3, 5, 4, 6, 1, 4, 6, 1, 3, 1, 5, 2, 5, 2, 6, 5, 1, 2, 1, 1, 4, 6, 5, 6, 3, 2, 6, 6, 5, 5, 1, 2, 6, 1, 6, 1, 3, 4, 6, 4, 6, 5, 4, 6, 2, 2, 4, 6, 6, 3, 6, 4, 2, 6, 3, 6, 2, 5, 2, 1, 1, 3, 1, 5, 2, 2, 5, 5, 1, 5, 5, 3, 1, 1, 6, 2, 1, 3, 1, 1, 5, 4, 2, 6, 2, 1, 6, 4, 5, 4, 3, 3, 6, 3, 6, 1, 2, 3, 1, 3, 5, 1, 1, 4, 4, 6, 4, 6, 3, 6, 6, 1, 1, 1, 3, 5, 4, 5, 1, 3, 5, 1, 3, 2, 1, 2, 5, 4, 2, 5, 2, 5, 4, 3, 5, 2, 1, 2, 2, 4, 2, 5, 4, 6, 5, 6, 3, 4, 1, 3, 1, 6, 6, 2, 3, 6, 1, 4, 6, 4, 4, 3, 5, 2, 6, 4, 1, 2, 4, 1, 5, 5, 3, 1, 5, 5, 2, 2, 2, 5, 1, 6, 2, 1, 2, 4, 5, 3, 3, 5, 2, 1, 1, 5, 6, 1, 1, 6, 3, 2, 1, 3, 6, 4, 2, 3, 2, 1, 5, 1, 1, 1, 1, 6, 1, 6, 4, 5, 6, 5, 1, 2, 1, 6, 2, 1, 4, 4, 2, 1, 5, 3, 6, 1, 2, 3, 1, 2, 1, 5, 6, 1, 4, 3, 2, 5, 4, 4, 6, 6, 2, 3, 2, 3, 3, 5, 6, 2, 4, 5, 1, 4, 2, 6, 1, 1, 4, 1, 5, 1, 4, 2, 3, 6, 2, 2, 3, 4, 2, 1, 1, 1, 1, 1, 4, 1, 6, 6, 4, 1, 1, 1, 1, 6, 5, 1, 2, 5, 3, 3, 6, 2, 4, 2, 2, 3, 3, 5, 1, 1, 3, 2, 2, 4, 6, 1, 1, 3, 4, 5, 5, 5, 6, 1, 2, 2, 5, 5, 6, 4, 5, 1, 5, 1, 1, 3, 4, 4, 1, 4, 4, 5, 4, 5, 3, 1, 6, 2, 6, 4, 1, 4, 3, 2, 3, 1, 6, 2, 2, 1, 1, 4, 4, 1, 3, 6, 2, 3, 1, 5, 2, 1, 1, 2, 5, 6, 1, 3, 4, 1, 1, 5, 6, 6, 4, 3, 3, 1, 6, 4, 6, 2, 3, 5, 1, 1, 2, 2, 3, 1, 2, 6, 3, 1, 2, 6, 3, 1, 1, 3, 5, 1, 5, 2, 2, 3, 4, 1, 4, 5, 5, 1, 1, 4, 1]
# 0.266
# 84
# 67
# 66
# 76
# 74
# Text(0.5, 0, 'Die Nunbers')

# %%
#biased = biased_die_simuations(trial_count)
#fair = fair_die_simulation(trial_count)

# mean1 = sum(fair) / len(fair)
# mean2 = sum(biased) /len(biased)
# print("Fair mean:")
# print(mean1)
# print("Biased_mean:")
# print(mean2)



# plt.hist(mean1,density=True,bins=20)
# plt.hist(mean2,density=True,bins=20)
# plt.title('Mean Calculation of fair and biased list')
# plt.ylabel('Time')
# plt.xlabel('Mean')
biasedRoll = (biased_die_simuations(500))
biased_meanList = [biasedRoll.count(1)/500,
                   biasedRoll.count(2)/500,
                   biasedRoll.count(3)/500,
                   biasedRoll.count(4)/500,
                   biasedRoll.count(5)/500,
                   biasedRoll.count(6)/500]

fair_meanList = [fair_die.count(1)/500,
                   fair_die.count(2)/500,
                   fair_die.count(3)/500,
                   fair_die.count(4)/500,
                   fair_die.count(5)/500,
                   fair_die.count(6)/500]
print("Biased Mean List:")
print(biased_meanList)
print("Fair Mean List:")
print(fair_meanList)


n_bins = [1,2,3,4,5,6]
plt.figure()
plt.subplot(2,2,1)
plt.plot(fair_meanList, n_bins , 'bo')
plt.plot(fair_meanList, n_bins , 'k')

plt.subplot(2,2,2)
plt.plot(biased_meanList, n_bins , 'bo')
plt.plot(biased_meanList, n_bins , 'k')

plt.subplot(2,2,(3,4))
plt.plot(biased_meanList, fair_meanList , 'bo')
plt.plot(biased_meanList, fair_meanList , 'k')


    
# biased_mean_list = ...
# unbiased_mean_list = ...
# Out:
# Biased Mean List:
# [0.264, 0.12, 0.16, 0.134, 0.154, 0.168]
# Fair Mean List:
# [0.176, 0.172, 0.15, 0.19, 0.158, 0.154]
